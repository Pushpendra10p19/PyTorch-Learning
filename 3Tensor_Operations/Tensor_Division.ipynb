# %%
import torch
a = torch.tensor([10,20,30,40,50])
b = torch.tensor([10,20,30,40,50])
print(a/b) # Division in which the value is get in points
print(a//b) # Division in which the value is get without point
# Out:
# tensor([1., 1., 1., 1., 1.])
# tensor([1, 1, 1, 1, 1])
