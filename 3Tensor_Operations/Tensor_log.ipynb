# %%
# log()  it is used to find the Natural logarithm(ln) 
# exp() & log() are opposite together 
import torch
a = torch.tensor([ 2.7183,  7.3891, 20.0855])
print(torch.log(a))
# Out:
# tensor([1.0000, 2.0000, 3.0000])
