# %%
import torch
a = torch.tensor([[1,2],[4,5]])
b = torch.tensor([[1,2],[4,5]])
# in this multiplication multiply of every element
print(a*b)

# in this multiplication follow the linear algebra rule
print(torch.matmul(a,b))
# Out:
# tensor([[ 1,  4],
#         [16, 25]])
# tensor([[ 9, 12],
#         [24, 33]])
