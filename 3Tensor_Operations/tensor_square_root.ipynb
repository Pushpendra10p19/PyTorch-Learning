# %%
import torch
a = torch.tensor([10,20,30,40,50])
b = torch.tensor([10,20,30,40,50])
print(torch.sqrt(a))
print(torch.sqrt(b))
# Out:
# tensor([3.1623, 4.4721, 5.4772, 6.3246, 7.0711])
# tensor([3.1623, 4.4721, 5.4772, 6.3246, 7.0711])
