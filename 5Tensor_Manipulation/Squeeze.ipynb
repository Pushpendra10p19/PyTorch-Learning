# %%
import torch
a = torch.tensor([[[1,3,3]]])
print(a.shape)
print(a.squeeze().shape)
print(a)

# Specific Squeeze()

x = a.squeeze(0) # remove 0 dimention
print(x.shape)
# Out:
# torch.Size([1, 1, 3])
# torch.Size([3])
# tensor([[[1, 3, 3]]])
# torch.Size([1, 3])
