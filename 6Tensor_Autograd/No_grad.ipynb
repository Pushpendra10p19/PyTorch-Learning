# %%
# `torch.no_grad()` is a context manager that temporarily disables gradient tracking.
# PyTorch will not build a computation graph for any operations performed within this block.

import torch
x = torch.tensor(2.0, requires_grad=True)
with torch.no_grad():
    y = x * 3
    print(y.requires_grad)
# Out:
# False
